# %% [markdown]
# ___
# # Linear Regression Project
#
# # Topic - Cause of death around the world.
#
# To assess the health status of a population is to focus on mortality – or concepts like child mortality or life expectancy, which are based on mortality estimates.

# %% [markdown]
# ## Import Libraries
# ** Import pandas, numpy, matplotlib,and seaborn. Then set %matplotlib inline
# (You'll import sklearn as you need it.)**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# ## Get the Data
#
# In this Dataset, we have Historical Data of different cause of deaths for all ages around the World. The key features of this Dataset are:
#
# * Country/Territory
# * Code
# * Year
# * Nutritional Deficiencies,
# * Malaria
# * Interpersonal Violence
# * HIV/AIDS
# * Tuberculosis
# * Cardiovascular Diseases
# * Self-harm
# * Environmental Heat and Cold Exposure
# * Conflict and Terrorism
# * Diabetes
# * Poisonings
# * Road Injuries

# %%
deaths = pd.read_csv('cause_of_deaths.csv')

# %% [markdown]
# **Check the head methods.**

# %%
deaths.head(20)
# Out:
#    Country/Territory Code  Year  Nutritional Deficiencies  Malaria  \
# 0        Afghanistan  AFG  1990                      2087       93
# 1        Afghanistan  AFG  1991                      2153      189
# 2        Afghanistan  AFG  1992                      2441      239
# 3        Afghanistan  AFG  1993                      2837      108
# 4        Afghanistan  AFG  1994                      3081      211
# 5        Afghanistan  AFG  1995                      3131      175
# 6        Afghanistan  AFG  1996                      3175      175
# 7        Afghanistan  AFG  1997                      3250      240
# 8        Afghanistan  AFG  1998                      3193      563
# 9        Afghanistan  AFG  1999                      3115      468
# 10       Afghanistan  AFG  2000                      3060      263
# 11       Afghanistan  AFG  2001                      2973      211
# 12       Afghanistan  AFG  2002                      2795     2883
# ...

# %% [markdown]
# # Dataframes used are :-
# * Country/Territory
# * Code
# * Year
# * Nutritional Deficiencies,
# * Malaria
# * Interpersonal Violence
# * HIV/AIDS
# * Tuberculosis
# * Cardiovascular Diseases
# * Self-harm
# * Environmental Heat and Cold Exposure
# * Conflict and Terrorism
# * Diabetes
# * Poisonings
# * Road Injuries

# %%
deaths.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6120 entries, 0 to 6119
# Data columns (total 7 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Country/Territory         6120 non-null   object
#  1   Code                      6120 non-null   object
#  2   Year                      6120 non-null   int64
#  3   Nutritional Deficiencies  6120 non-null   int64
#  4   Malaria                   6120 non-null   int64
#  5   Interpersonal Violence    6120 non-null   int64
#  6   Cardiovascular Diseases   6120 non-null   int64
# dtypes: int64(5), object(2)
# memory usage: 334.8+ KB

# %% [markdown]
# # Descriptive statistics.

# %%
deaths.describe()
# Out:
#               Year  Nutritional Deficiencies        Malaria  \
# count  6120.000000               6120.000000    6120.000000
# mean   2004.500000               2253.600000    4140.960131
# std       8.656149              10483.633601   18427.753137
# min    1990.000000                  0.000000       0.000000
# 25%    1997.000000                  9.000000       0.000000
# 50%    2004.500000                119.000000       0.000000
# 75%    2012.000000               1167.250000     393.000000
# max    2019.000000             268223.000000  280604.000000
#
#        Interpersonal Violence  Cardiovascular Diseases
# count             6120.000000             6.120000e+03
# mean              2083.797222             7.316045e+04
# std               6917.006075             2.915775e+05
# min                  0.000000             4.000000e+00
# 25%                 40.000000             2.028000e+03
# 50%                265.000000             1.174200e+04
# ...

# %% [markdown]
# ## Exploratory Data Analysis
#
#
# We'll only be using the numerical data of the csv file.
# ___
# **Use seaborn to create a jointplot to compare the Time on Website and Yearly Amount Spent columns. Does the correlation make sense?**

# %%
deaths.columns
# Out:
# Index(['Country/Territory', 'Code', 'Year', 'Nutritional Deficiencies',
#        'Malaria', 'Interpersonal Violence', 'Cardiovascular Diseases'],
#       dtype='object')

# %% [markdown]
# # Pairplot
# A pairplot plot a pairwise relationships in a dataset.
# The pairplot function creates a grid of Axes such that each variable in data will by shared in the y-axis
# across a single row and in the x-axis across a single column

# %%
sns.pairplot(deaths)

# %% [markdown]
# # Heatmap
# Axes-level function and will draw the heatmap into the currently-active Axes.

# %%
sns.heatmap(deaths.corr())
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Year vs Total no. of Deaths for Canada

# %%
cause_of_deaths = ['Nutritional Deficiencies','Malaria','Interpersonal Violence', 'Cardiovascular Diseases']

deaths['No_of_Deaths'] = deaths[cause_of_deaths].sum(axis=1)
Total_no_of_Deaths_df = deaths[deaths['Country/Territory']=='Canada'].sort_values(by='No_of_Deaths',ascending=False)

plt.figure(figsize=(8,4),dpi=200)
sns.scatterplot(data=Total_no_of_Deaths_df, x='Year', y='No_of_Deaths')
plt.xlabel("Year")
plt.ylabel("Total no.of Deaths")
plt.title("Year Vs. Total no.of Deaths for Canada")
plt.show();

# %% [markdown]
# # Year vs Total no. of Deaths for India

# %%
cause_of_deaths = ['Nutritional Deficiencies','Malaria','Interpersonal Violence', 'Cardiovascular Diseases']

deaths['No_of_Deaths'] = deaths[cause_of_deaths].sum(axis=1)
Total_no_of_Deaths_df = deaths[deaths['Country/Territory']=='India'].sort_values(by='No_of_Deaths',ascending=False)

plt.figure(figsize=(8,4),dpi=200)
sns.scatterplot(data=Total_no_of_Deaths_df, x='Year', y='No_of_Deaths')
plt.xlabel("Year")
plt.ylabel("Total no.of Deaths")
plt.title("Year Vs. Total no.of Deaths for India")
plt.show();

# %%
diseases =  ['Nutritional Deficiencies','Malaria','Interpersonal Violence', 'Cardiovascular Diseases']
for x in diseases:
    if deaths[x].dtypes != 'string':
        #print(x)
        data = deaths.groupby(['Country/Territory'])[x].sum().sort_values(ascending =False)[:10]
        plt.figure(figsize=(12,6))
        plt.bar(data=data ,x = data.index , height = data.values, width=0.9, color = ['crimson','blue','green', 'yellow', 'magenta'])
        plt.xticks(rotation='vertical')
        plt.xlabel("COUNTRIES" , size = 10)
        plt.ylabel(x.upper()+' DEATHS PER MILLION')
        plt.title("COUNTRIES WITH HIGHEST "+x.upper()+' DEATHS')

# %% [markdown]
# # Training a Linear Regression Model
#
# Now that we've explored the data a bit, let's go ahead and split the data into training and testing sets.
# ** Set a variable X equal to the numerical features of the customers and a variable y equal to the "Yearly Amount Spent" column. **
#
# X and y arrays.

# %%
X = deaths[['Nutritional Deficiencies','Malaria', 'Interpersonal Violence', 'Cardiovascular Diseases']]

cause_of_deaths = ['Nutritional Deficiencies','Malaria','Interpersonal Violence', 'Cardiovascular Diseases']

deaths['Total_no_of_Deaths'] = deaths[cause_of_deaths].sum(axis=1)

# print(deaths['Total_no_of_Deaths'])
y = deaths['Total_no_of_Deaths']

# %% [markdown]
# # Train Test Split
# ** Use model_selection.train_test_split from sklearn to split the data into training and testing sets. Set test_size=0.4 and random_state=101**

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=101)

# %% [markdown]
# ## Creating and Training the Model
#
# Now its time to train our model on our training data!
#
# ** Import LinearRegression from sklearn.linear_model **

# %%
from sklearn.linear_model import LinearRegression

# %%
lm = LinearRegression()

# %%
lm.fit(X_train,y_train)
# Out:
# LinearRegression()

# %% [markdown]
# # Model Evaluation
# Create an instance of a LinearRegression() model named lm.

# %%
# print the intercept
print(lm.intercept_)
# Out:
# 2.9103830456733704e-11

# %%
coeff_df = pd.DataFrame(lm.coef_,X.columns,columns=['Coefficient'])
coeff_df
# Out:
#                           Coefficient
# Nutritional Deficiencies          1.0
# Malaria                           1.0
# Interpersonal Violence            1.0
# Cardiovascular Diseases           1.0

# %% [markdown]
# # Predictions from our Model

# %%
predictions = lm.predict(X_test)

# %%
plt.scatter(y_test,predictions)

# %% [markdown]
# **Print out the coefficients of the model**

# %%
sns.histplot((y_test-predictions),bins=50);

# %% [markdown]
# # Regression Evaluation Metrics
#
# Comparing these metrics:
#
# MAE is the easiest to understand, because it's the average error.
# MSE is more popular than MAE, because MSE "punishes" larger errors, which tends to be useful in the real world.
# RMSE is even more popular than MSE, because RMSE is interpretable in the "y" units.
# All of these are loss functions, because we want to minimize them.

# %%
from sklearn import metrics
print('MAE:', metrics.mean_absolute_error(y_test, predictions))
print('MSE:', metrics.mean_squared_error(y_test, predictions))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, predictions)))
# Out:
# MAE: 5.177548963275346e-11
# MSE: 2.844476761954802e-20
# RMSE: 1.6865576663591442e-10

# %% [markdown]
# # Result

# %% [markdown]
# CHINA , INDIA AND USA face the largest brunt of deaths due to diseases in the world Cardiovascular diseases , Neoplasms (Malignancy/Cancer) and Lower Respiratory Tract Infections (ex : Pneumonia) are the top 3 killer disases in the world.
